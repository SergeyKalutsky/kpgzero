# %%
def fibonacci(n):
    if n in (1, 2):
        return 1
    return fibonacci(n - 1) + fibonacci(n - 2)
fibonacci(100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-2ddb89bd4c08> in <module>
#       3         return 1
#       4     return fibonacci(n - 1) + fibonacci(n - 2)
# ----> 5 fibonacci(100)
#
# <ipython-input-31-2ddb89bd4c08> in fibonacci(n)
#       2     if n in (1, 2):
#       3         return 1
# ----> 4     return fibonacci(n - 1) + fibonacci(n - 2)
#       5 fibonacci(100)
#
# <ipython-input-31-2ddb89bd4c08> in fibonacci(n)
#       2     if n in (1, 2):
#       3         return 1
# ----> 4     return fibonacci(n - 1) + fibonacci(n - 2)
#       5 fibonacci(100)
#
# <ipython-input-31-2ddb89bd4c08> in fibonacci(n)
#       2     if n in (1, 2):
#       3         return 1
# ----> 4     return fibonacci(n - 1) + fibonacci(n - 2)
#       5 fibonacci(100)
#
# <ipython-input-31-2ddb89bd4c08> in fibonacci(n)
#       2     if n in (1, 2):
#       3         return 1
# ...
